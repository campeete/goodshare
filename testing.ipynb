# %%
import pandas as pd

df = pd.read_csv("data/ipc_predicted_vs_actual.csv")

# %%
df
# Out:
#       country country_code   admin_0  admin_1 projection_start projection_end  \
# 0    Ethiopia           ET  Ethiopia      NaN       2020-01-01     2020-01-31
# 1    Ethiopia           ET  Ethiopia      NaN       2020-02-01     2020-02-29
# 2    Ethiopia           ET  Ethiopia      NaN       2020-03-01     2020-03-31
# 3    Ethiopia           ET  Ethiopia      NaN       2020-04-01     2020-04-30
# 4    Ethiopia           ET  Ethiopia      NaN       2020-05-01     2020-05-31
# ..        ...          ...       ...      ...              ...            ...
# 349   Somalia           SO   Somalia      NaN       2024-07-01     2024-07-31
# 350   Somalia           SO   Somalia      NaN       2024-08-01     2024-08-31
# 351   Somalia           SO   Somalia      NaN       2024-09-01     2024-09-30
# 352   Somalia           SO   Somalia      NaN       2024-10-01     2024-10-31
# 353   Somalia           SO   Somalia      NaN       2024-11-01     2024-11-30
#
# ...
